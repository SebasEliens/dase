# %% [raw]
# ---
# title: "The story of 3 graphs"
# author: "Sebas Eliëns"
# date: "2024-01-08"
# categories: [inequality, resources, anthropocene]
# draft: true
# ---

# %% [markdown]
# A good friend of mine once organized a hackaton for data scientists. He is a good public speaker, and in his opening presentation he told the story of three graphs. These graphs show trends in human impact, natural resources and inequality over time. Two of those went dramatically up while one went down. While a compelling story, some pesky data scientist asked about the data source, and it turned out that the graph was, in fact, more of an illustration and, while undoubtably true, the story was just that: a story. Ever since I have had the plan of recreating that graph with real data and see exactly how true that story is, or in the words of the [How to save a planet podcast](https://gimletmedia.com/shows/howtosaveaplanet): How screwed are we?
#
# ![The three graphs of the story](image.jpg)

# %% [markdown]
# ### Human impact
#
# https://www.anthroponumbers.org/catalog/
#
# ### Natural resources
#
# https://www.theworldcounts.com/stories/depletion-of-natural-resources
#
# https://www.ers.usda.gov/about-ers/partnerships/strengthening-statistics-through-the-icars/natural-resources-datasets/
#
# ### Inequality
#
# https://wid.world/
#
# https://ourworldindata.org/economic-inequality

# %%
3+3
# Out:
# 6
